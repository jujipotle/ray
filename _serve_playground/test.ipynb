# %%
from openai import OpenAI

# Initialize client
client = OpenAI(base_url="http://localhost:8000/v1", api_key="fake-key")

# %%
# Basic chat completion with streaming
response = client.chat.completions.create(
    model="qwen-0.5b",
    messages=[{"role": "user", "content": ""}],
    stream=True
)

for chunk in response:
    if chunk.choices[0].delta.content is not None:
        print(chunk.choices[0].delta.content, end="", flush=True)
# Out:
# As an artificial intelligence language model
# , I do not fall into the category of a biological species like a human being. However, I can understand that humans have a lot in common. What do you want to know about AI technology, language, or any other specific topic? Please let me know and I will do my best to help you.
