# %%
# %pip install matplotlib seaborn -q
# %run /home/ray/default/work/ray/_prefix_aware_playground/shared/visualization_functions.py
# %run /home/ray/default/work/ray/_prefix_aware_playground/shared/visualization_functions2.py
import visualization_functions
import visualization_functions2

# %%
plot_metric(
    json_file_path="/home/ray/default/work/ray/_prefix_aware_playground/inside_ray/results/vllm_metrics/random_1744240419.json",
    metric_name="ray_vllm:time_to_first_token_seconds_sum",
    title=""
)
# Out:
# [INFO] Loading JSON from: /home/ray/default/work/ray/_prefix_aware_playground/inside_ray/results/vllm_metrics/random_1744240419.json
# [INFO] Loaded 457 timestamps.
# [INFO] Found 4 replicas with metric 'ray_vllm:time_to_first_token_seconds_sum'.
# [INFO] Plotted average line.

# %%
plot_average_vllm_metrics("/home/ray/default/work/ray/_prefix_aware_playground/inside_ray/results/vllm_metrics/random_1744240419.json", "ray_vllm:time_to_first_token_seconds", title="TTFT", window_sec=5)
# Out:
# [INFO] Loaded 457 timestamps.
# [INFO] Found 4 replicas reporting 'ray_vllm:time_to_first_token_seconds'.
# [INFO] Replica 06f19f3d33107890f01bb44258d6c4141736d3b7f8ae3a7228de1967 has non-zero values.
# [INFO] Replica 284a8f08d493582756a2872421aea3b6c6dcc75dd4baa86826e17300 has non-zero values.
# [INFO] Replica 3d38b9ed397da69a8f0f4e92060cd1053a70578d62bca07abd0416c5 has non-zero values.
# [INFO] Replica 737f81a4b0681b893a0b6ab97faf0bb90c8a56eac5012f2222cc4689 has non-zero values.

# %%
for metric in available_metrics:
    plot_metric_by_strategy("/home/ray/default/work/ray/_prefix_aware_playground/inside_ray/results/chosen_sweep_results.csv", metric)

# %%
plot_load_distribution("/home/ray/default/work/ray/_prefix_aware_playground/inside_ray/results/load_distributions/random_1744236331.json")
