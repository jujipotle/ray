# %% [markdown]
# ## Install dependencies

# %%
pip install vllm huggingface-cli python-multipart matplotlib datasets

# %% [markdown]
# ## Start vLLM servers

# %%
python run_replicas.py --host 127.0.0.1 --worker-ports 8001,8002,8003,8004 --gpu-indices 0,1,2,3 --model-name "Qwen/Qwen2.5-1.5B-Instruct" --enable-prefix-caching

# %% [markdown]
# ## Start Server (Router Instance)

# %%
python server3.py --worker-urls http://localhost:8001 http://localhost:8002 http://localhost:8003 http://localhost:8004 --host 127.0.0.1 --port 8000 --policy round_robin

# %% [markdown]
# ## Prefix-caching benchmark (single)

# %%
python3 -m bench_serving --backend vllm --host 127.0.0.1 --port 8000 --dataset-name generated-shared-prefix --gen-num-groups 64 --gen-prompts-per-group 16 --gen-system-prompt-len 2048 --gen-question-len 128 --gen-output-len 256 --max-concurrency 32
python benchmark_serving_kubeai.py --backend vllm --host 127.0.0.1 --port 8000 --model Qwen/Qwen2.5-1.5B-Instruct --dataset-name sharegpt --dataset-path /home/ray/default/work/ray/prefix_aware_playground/sharegpt.json --max-concurrency 128 --num-prompts 800 --max-conversations 800

# %%
python3 -m bench_serving --backend vllm --host 127.0.0.1 --port 8000 --dataset-name generated-shared-prefix --gen-num-groups 1 --gen-prompts-per-group 1 --gen-system-prompt-len 2048 --gen-question-len 128 --gen-output-len 256 --max-concurrency 32
python benchmark_serving_kubeai.py --backend vllm --host 127.0.0.1 --port 8000 --model Qwen/Qwen2.5-1.5B-Instruct --dataset-name sharegpt --dataset-path /home/ray/default/work/ray/prefix_aware_playground/sharegpt.json --max-concurrency 128 --num-prompts 1 --max-conversations 800

# %% [markdown]
# ## Prefix-cache benchmark (sweep)
# Set `DEFAULT_CONFIG` in `bench_prefix_sweep.py` then run `python bench_prefix_sweep.py`

# %% [markdown]
# ## Analyze results
# Copy the selected results from `sweep_results.csv` into `chosen_results.csv` and run `display_prefix_sweep.ipynb`
